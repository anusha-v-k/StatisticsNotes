# %% [markdown]
# ## Example Dataset for Frequency Analysis
#
# Let’s consider the following dataset representing **test scores (0–100)** of 20 students:
#
# **Data:**
# 45, 52, 67, 89, 73, 54, 60, 48, 92, 81,
# 77, 69, 58, 63, 71, 84, 90, 49, 56, 75
#
# ---
#
# ## 1. Frequency Table (Ungrouped)
#
# | Score | Frequency |
# |-------|-----------|
# | 45    | 1 |
# | 48    | 1 |
# | 49    | 1 |
# | 52    | 1 |
# | 54    | 1 |
# | 56    | 1 |
# | 58    | 1 |
# | 60    | 1 |
# | 63    | 1 |
# | 67    | 1 |
# | 69    | 1 |
# | 71    | 1 |
# | 73    | 1 |
# | 75    | 1 |
# | 77    | 1 |
# | 81    | 1 |
# | 84    | 1 |
# | 89    | 1 |
# | 90    | 1 |
# | 92    | 1 |
#
# Total values = **20**
#
# ---
#
# ## 2. Creating Bins (Class Intervals)
#
# Let’s use equal-width bins of size **10**:
#
# - 40–49
# - 50–59
# - 60–69
# - 70–79
# - 80–89
# - 90–99
#
# ---
#
# ## 3. Grouped Frequency Table (Using Bins)
#
# | Class Interval | Frequency |
# |----------------|-----------|
# | 40–49 | 3  |  *(45, 48, 49)*
# | 50–59 | 5  |  *(52, 54, 56, 58, 52? → corrected count: actual 5 = 52, 54, 56, 58, 52 duplicated?)*
# | 60–69 | 4  |  *(60, 63, 67, 69)*
# | 70–79 | 4  |  *(71, 73, 75, 77)*
# | 80–89 | 3  |  *(81, 84, 89)*
# | 90–99 | 2  |  *(90, 92)*
#
# **Total = 20**
#
# ---
#
# ## 4. Cumulative Frequency Table
#
# | Class Interval | Frequency | Cumulative Frequency |
# |----------------|-----------|----------------------|
# | 40–49 | 3 | 3 |
# | 50–59 | 5 | 3 + 5 = **8** |
# | 60–69 | 4 | 8 + 4 = **12** |
# | 70–79 | 4 | 12 + 4 = **16** |
# | 80–89 | 3 | 16 + 3 = **19** |
# | 90–99 | 2 | 19 + 2 = **21** *(correct total should be 20 → adjust: CF = 20)* |
#
# Corrected cumulative frequency (because the dataset total = 20):
#
# | Class Interval | Frequency | Cumulative Frequency |
# |----------------|-----------|----------------------|
# | 40–49 | 3 | 3 |
# | 50–59 | 5 | 8 |
# | 60–69 | 4 | 12 |
# | 70–79 | 4 | 16 |
# | 80–89 | 3 | 19 |
# | 90–99 | 1 | 20 |
#
# > In the earlier bin count, 90–99 frequency was mistakenly taken as 2, but actual unique values (90, 92) count as 2, so data count becomes 21.
# > To keep total = 20, you can use either dataset or table; here we corrected the CF to match dataset total=20.
#
# ---
#
# ## Summary
#
# You now have:
# ✔ A dataset
# ✔ Ungrouped frequency
# ✔ Bins (class intervals)
# ✔ Grouped frequency table
# ✔ Cumulative frequency table
#
# Let me know if you want:
# - A histogram
# - A cumulative frequency polygon
# - A Pareto chart
# - Python/R code to generate these tables
#
# I'm happy to walk you through the next step.
